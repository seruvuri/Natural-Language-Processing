# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sentence=['the glass of milk',
        'the glass of tea',
        'i am a good boy',
        'understand the meaning of words',
        'your videos are good',]
sentence
# Out:
# ['the glass of milk',
#  'the glass of tea',
#  'i am a good boy',
#  'understand the meaning of words',
#  'your videos are good']

# %% [markdown]
# ## one hot representation

# %%
voc_size=10000

# %%
onehot=[one_hot(words,voc_size)for words in sentence]
print(onehot)
# Out:
# [[2623, 1077, 3514, 1386], [2623, 1077, 3514, 9179], [6666, 4631, 8530, 6075, 530], [2419, 2623, 6913, 3514, 5252], [3878, 6297, 4241, 6075]]

# %% [markdown]
# ## Word Embedding Representation

# %%
from tensorflow.keras.layers import Embedding

#the reason we use pad_sequences is while providing sentence to embending layer is to make the size of all sentence is same for good performance  
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
#we are setting the lenght of each sentence to 8
#when we give padding=pre it will add 0 before the sentence
sent_length=8
embedded_docs=pad_sequences(onehot,padding='pre',maxlen=sent_length)
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 2623, 1077, 3514, 1386],
#        [   0,    0,    0,    0, 2623, 1077, 3514, 9179],
#        [   0,    0,    0, 6666, 4631, 8530, 6075,  530],
#        [   0,    0,    0, 2419, 2623, 6913, 3514, 5252],
#        [   0,    0,    0,    0, 3878, 6297, 4241, 6075]])

# %%
dim=10
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 8, 10)             100000
#
# ...
# Total params: 100,000
# Trainable params: 100,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(model.predict(embedded_docs))
# Out:
# 1/1 [==============================] - 0s 153ms/step
# [[[ 0.00687661  0.02688781  0.00259571 -0.02677485  0.04943163
#     0.04102368 -0.04057376 -0.04341665 -0.00969196  0.03749999]
#   [ 0.00687661  0.02688781  0.00259571 -0.02677485  0.04943163
#     0.04102368 -0.04057376 -0.04341665 -0.00969196  0.03749999]
#   [ 0.00687661  0.02688781  0.00259571 -0.02677485  0.04943163
#     0.04102368 -0.04057376 -0.04341665 -0.00969196  0.03749999]
#   [ 0.00687661  0.02688781  0.00259571 -0.02677485  0.04943163
#     0.04102368 -0.04057376 -0.04341665 -0.00969196  0.03749999]
#   [-0.03188433 -0.04825169 -0.01529948 -0.00907277 -0.01773862
#     0.02999946 -0.03898541  0.01525409 -0.04009317  0.04693779]
#   [-0.01570213  0.01546696  0.04725624  0.00682003  0.03591254
#    -0.00446417  0.02617142 -0.00460641  0.02514977 -0.04561834]
#   [ 0.03347409  0.03321413 -0.01664761 -0.00383478  0.00315468
#    -0.04816283  0.03188724 -0.02146313  0.01783258  0.04481028]
# ...
